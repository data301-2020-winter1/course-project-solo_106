# %%
import pandas as pd
import os

os.getcwd()

df = pd.read_csv('/Users/Osaze/301/course-project-solo_106/data/raw/data.csv')
df
# Out:
#              id              name  year  year_index  total_players  \
# 0      rosede01      Derrick Rose  2009           0            445
# 1      rosede01      Derrick Rose  2010           1            442
# 2      rosede01      Derrick Rose  2011           2            452
# 3      rosede01      Derrick Rose  2012           3            478
# 4      rosede01      Derrick Rose  2013           4            469
# ...         ...               ...   ...         ...            ...
# 14977     12916  Francisco Lindor  2016           1           1353
# 14978     12916  Francisco Lindor  2017           2           1358
# 14979     15429       Kris Bryant  2015           0           1348
# 14980     15429       Kris Bryant  2016           1           1353
# 14981     15429       Kris Bryant  2017           2           1358
#
#        peak_year_index   rank    dnp  sport_name league stat_prop  stat_val  \
# 0                    2  113.0  False  basketball    nba      vorp       1.1
# ...
